# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

df= pd.read_csv("Salary_dataset.csv")
x= np.array(df['YearsExperience'])
y= np.array(df['Salary'])

k, d = np.polyfit(x,y,1)
y_pred = k*x + d
print("slope: ",k)
print("intercept: ",d)


plt.plot(x, y, '.')
plt.plot(x, y_pred)
plt.show()

#using sklearn 
from sklearn.linear_model import LinearRegression
x= np.array(df['YearsExperience']).reshape((-1,1))

reg= LinearRegression()
reg.fit(x,y)

r_squared= reg.score(x,y)
print("r squared: ",r_squared)
print("regression coef:", reg.coef_)
print("regression intercept:", reg.intercept_)
# Out:
# slope:  9449.962321455074
# intercept:  24848.20396652318
# r squared:  0.9569566641435086
# regression coef: [9449.96232146]
# regression intercept: 24848.203966523208

# %%
import LinearRegression as LR
a= LR.LinearRegression(x,y)
# Out:
# Intercept: [24848.20396652]
# Slope: [9449.96232146]
